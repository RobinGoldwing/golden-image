# %%
# %matplotlib inline

import sys, os;

import numpy as np;

import matplotlib as mplt;

from matplotlib import pyplot as plt;

import skimage as ski;

# %%
img = ski.io.imread("https://cdn.shopify.com/s/files/1/0320/5854/0091/products/R12-915_7c87d1e5-1a27-4aca-927c-5d489df74359.jpg?v=1603561964");

ski.io.imshow(img)

# %%
img_ = img.copy()

w_mask = img_ > 250

masked = img * w_mask

ski.io.imshow(masked)

# %%
diff = (img_ - masked)

ski.io.imshow(diff)

#img_[w_mask]=[255,255,0]
#ski.io.imshow(img_)
